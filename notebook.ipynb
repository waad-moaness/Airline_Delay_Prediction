# %%
import pandas as pd

# %%
df = pd.read_csv("data/Airline_Delay_Cause.csv",engine='python')
df
# Out:
#         year  month carrier          carrier_name airport  \
# 0       2022      5      9E     Endeavor Air Inc.     ABE
# 1       2022      5      9E     Endeavor Air Inc.     ABY
# 2       2022      5      9E     Endeavor Air Inc.     ACK
# 3       2022      5      9E     Endeavor Air Inc.     AEX
# 4       2022      5      9E     Endeavor Air Inc.     AGS
# ...      ...    ...     ...                   ...     ...
# 277305  2005     11      DL  Delta Air Lines Inc.     PSC
# 277306  2005     11      DL  Delta Air Lines Inc.     PSP
# 277307  2005     11      DL  Delta Air Lines Inc.     PVD
# 277308  2005     11      DL  Delta Air Lines Inc.     RDU
# 277309  2005     11      DL  Delta Air Lines Inc.     RIC
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0
# 1                  Albany, GA: Southwest Georgia Regional         91.0
# ...

# %%
df.isnull().sum()
# Out:
# year                     0
# month                    0
# carrier                  0
# carrier_name             0
# airport                  3
# airport_name             0
# arr_flights            462
# arr_del15              701
# carrier_ct             461
# weather_ct             463
# nas_ct                 457
# security_ct            458
# late_aircraft_ct       458
# arr_cancelled          458
# arr_diverted           460
# arr_delay              461
# carrier_delay          459
# weather_delay          458
# nas_delay              458
# security_delay         460
# late_aircraft_delay    458
# dtype: int64

# %%
df.dropna(inplace = True )

# %%
df.isnull().sum()
# Out:
# year                   0
# month                  0
# carrier                0
# carrier_name           0
# airport                0
# airport_name           0
# arr_flights            0
# arr_del15              0
# carrier_ct             0
# weather_ct             0
# nas_ct                 0
# security_ct            0
# late_aircraft_ct       0
# arr_cancelled          0
# arr_diverted           0
# arr_delay              0
# carrier_delay          0
# weather_delay          0
# nas_delay              0
# security_delay         0
# late_aircraft_delay    0
# dtype: int64

# %%
df
# Out:
#         year  month carrier          carrier_name airport  \
# 0       2022      5      9E     Endeavor Air Inc.     ABE
# 1       2022      5      9E     Endeavor Air Inc.     ABY
# 2       2022      5      9E     Endeavor Air Inc.     ACK
# 3       2022      5      9E     Endeavor Air Inc.     AEX
# 4       2022      5      9E     Endeavor Air Inc.     AGS
# ...      ...    ...     ...                   ...     ...
# 277304  2005     11      DL  Delta Air Lines Inc.     PNS
# 277305  2005     11      DL  Delta Air Lines Inc.     PSC
# 277306  2005     11      DL  Delta Air Lines Inc.     PSP
# 277307  2005     11      DL  Delta Air Lines Inc.     PVD
# 277308  2005     11      DL  Delta Air Lines Inc.     RDU
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0
# 1                  Albany, GA: Southwest Georgia Regional         91.0
# ...
